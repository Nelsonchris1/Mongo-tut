# %%
data = ({'_id': '6229b694bf76c6304096974a', 'type': 'strawberries', 'quantity': 7},
{'_id': '6229b694bf76c6304096974b', 'type': 'bananas', 'quantity': 100},
{'_id': '6229b694bf76c6304096974c', 'type': 'apples', 'quantity': 7})

# %%
new_data = pd.DataFrame(data)

# %%
new_data
# Out:
#                         _id          type  quantity
# 0  6229b694bf76c6304096974a  strawberries         7
# 1  6229b694bf76c6304096974b       bananas       100
# 2  6229b694bf76c6304096974c        apples         7

# %%
clust = "mongodb+srv://Nelson:blessing@cluster0.ieu4h.mongodb.net/test?retryWrites=true&w=majority"
client = pymongo.MongoClient(clust)

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
db = client.sample_airbnb

# %%
db.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
reviews = db.listingsAndReviews

# %%
# %%time
results = reviews.find()
# Out:
# Wall time: 0 ns

# %%
# %%time
import pandas as pd
real = pd.DataFrame(results)
# Out:
# Wall time: 1min 46s

# %%
# %%time
reviews_db = pd.json_normalize(list(results))
# Out:
# Wall time: 47.5 s

# %%
reviews_db.head(1)
# Out:
#         _id                            listing_url                     name  \
# 0  10006546  https://www.airbnb.com/rooms/10006546  Ribeira Charming Duplex
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
#
#                                                notes  \
# 0  Lose yourself in the narrow streets and stairc...
#
#                                              transit  \
# 0  Transport: • Metro station and S. Bento railwa...
#
#                                               access  \
# 0  We are always available to help guests. The ho...
#
# ...

# %%
real.head(1)
# Out:
#         _id                            listing_url                     name  \
# 0  10006546  https://www.airbnb.com/rooms/10006546  Ribeira Charming Duplex
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
#
#                                                notes  \
# 0  Lose yourself in the narrow streets and stairc...
#
#                                              transit  \
# 0  Transport: • Metro station and S. Bento railwa...
#
#                                               access  \
# 0  We are always available to help guests. The ho...
#
# ...

# %%
json_list = [
    { 
        'class': 'Year 1', 
        'student count': 20, 
        'room': 'Yellow',
        'info': {
            'teachers': { 
                'math': 'Rick Scott', 
                'physics': 'Elon Mask' 
            }
        },
        'students': [
            { 
                'name': 'Tom', 
                'sex': 'M', 
                'grades': { 'math': 66, 'physics': 77 } 
            },
            { 
                'name': 'James', 
                'sex': 'M', 
                'grades': { 'math': 80, 'physics': 78 } 
            },
        ]
    },
    { 
        'class': 'Year 2', 
        'student count': 25, 
        'room': 'Blue',
        'info': {
            'teachers': { 
                'math': 'Alan Turing', 
                'physics': 'Albert Einstein' 
            }==
        },
        'students': [
            { 'name': 'Tony', 'sex': 'M' },
            { 'name': 'Jacqueline', 'sex': 'F' },
        ]
    },
]

# %%
import pandas as pd

# %%
table1 = pd.json_normalize(json_list)

# %%
table1
# Out:
#     class  student count    room  \
# 0  Year 1             20  Yellow
# 1  Year 2             25    Blue
#
#                                             students info.teachers.math  \
# 0  [{'name': 'Tom', 'sex': 'M', 'grades': {'math'...         Rick Scott
# 1  [{'name': 'Tony', 'sex': 'M'}, {'name': 'Jacqu...        Alan Turing
#
#   info.teachers.physics
# 0             Elon Mask
# 1       Albert Einstein

# %%
table = pd.json_normalize(json_list, record_path=['students'], meta=['class', 'room', ['info', 'teachers', 'math']])
table.head()
# Out:
#          name sex  grades.math  grades.physics   class    room  \
# 0         Tom   M         66.0            77.0  Year 1  Yellow
# 1       James   M         80.0            78.0  Year 1  Yellow
# 2        Tony   M          NaN             NaN  Year 2    Blue
# 3  Jacqueline   F          NaN             NaN  Year 2    Blue
#
#   info.teachers.math
# 0         Rick Scott
# 1         Rick Scott
# 2        Alan Turing
# 3        Alan Turing
